# %%
import pandas as pd
import numpy as np
import libs.DataCleaning as dc

# %%
df = pd.read_csv('data/show_no_show.csv')

# %% [markdown]
# # Cleaning

# %%
df.tail()
# Out:
#         Unnamed: 0     PatientId  AppointmentID Gender  \
# 110522      110522  2.572134e+12        5651768      F
# 110523      110523  3.596266e+12        5650093      F
# 110524      110524  1.557663e+13        5630692      F
# 110525      110525  9.213493e+13        5630323      F
# 110526      110526  3.775115e+14        5629448      F
#
#                     ScheduledDay            AppointmentDay  Age Neighbourhood  \
# 110522 2016-05-03 09:15:35+00:00 2016-06-07 00:00:00+00:00   56   MARIA ORTIZ
# 110523 2016-05-03 07:27:33+00:00 2016-06-07 00:00:00+00:00   51   MARIA ORTIZ
# 110524 2016-04-27 16:03:52+00:00 2016-06-07 00:00:00+00:00   21   MARIA ORTIZ
# 110525 2016-04-27 15:09:23+00:00 2016-06-07 00:00:00+00:00   38   MARIA ORTIZ
# 110526 2016-04-27 13:30:56+00:00 2016-06-07 00:00:00+00:00   54   MARIA ORTIZ
#
#         Scholarship  Hipertension  Diabetes Alcoholism  Handcap  SMS_received  \
# 110522            0             0         0       None        0             1
# 110523            0             0         0       None        0             1
# 110524            0             0         0       None        0             1
# 110525            0             0         0       None        0             1
# 110526            0             0         0       None        0             1
#
#        No-show
# 110522      No
# 110523      No
# 110524      No
# 110525      No
# 110526      No

# %% [markdown]
# ## String Dates to Date

# %%
dc.transform_dates_to_date_dtype(df,['ScheduledDay','AppointmentDay'])

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# PatientId                     float64
# AppointmentID                   int64
# Gender                         object
# ScheduledDay      datetime64[ns, UTC]
# AppointmentDay    datetime64[ns, UTC]
# Age                             int64
# Neighbourhood                  object
# Scholarship                     int64
# Hipertension                    int64
# Diabetes                        int64
# Alcoholism                     object
# Handcap                         int64
# SMS_received                    int64
# No-show                        object
# dtype: object

# %% [markdown]
# ## Eliminate Unnecesary Columns

# %%
df.drop(columns=["Unnamed: 0","PatientId"], inplace= True)

# %% [markdown]
# ## Rename Columns

# %%
df.rename(columns={"Handcap": "Handicap"})
# Out:
#         AppointmentID Gender              ScheduledDay  \
# 0             5642903      F 2016-04-29 18:38:08+00:00
# 1             5642503      M 2016-04-29 16:08:27+00:00
# 2             5642549      F 2016-04-29 16:19:04+00:00
# 3             5642828      F 2016-04-29 17:29:31+00:00
# 4             5642494      F 2016-04-29 16:07:23+00:00
# ...               ...    ...                       ...
# 110522        5651768      F 2016-05-03 09:15:35+00:00
# 110523        5650093      F 2016-05-03 07:27:33+00:00
# 110524        5630692      F 2016-04-27 16:03:52+00:00
# 110525        5630323      F 2016-04-27 15:09:23+00:00
# 110526        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1      2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2      2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3      2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4      2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# ...                          ...  ...                ...          ...
# 110522 2016-06-07 00:00:00+00:00   56        MARIA ORTIZ            0
# 110523 2016-06-07 00:00:00+00:00   51        MARIA ORTIZ            0
# 110524 2016-06-07 00:00:00+00:00   21        MARIA ORTIZ            0
# 110525 2016-06-07 00:00:00+00:00   38        MARIA ORTIZ            0
# 110526 2016-06-07 00:00:00+00:00   54        MARIA ORTIZ            0
#
#         Hipertension  Diabetes Alcoholism  Handicap  SMS_received No-show
# 0                  1         0       None         0             0      No
# 1                  0         0       None         0             0      No
# 2                  0         0       None         0             0      No
# 3                  0         0       None         0             0      No
# 4                  1         1       None         0             0      No
# ...              ...       ...        ...       ...           ...     ...
# 110522             0         0       None         0             1      No
# 110523             0         0       None         0             1      No
# 110524             0         0       None         0             1      No
# 110525             0         0       None         0             1      No
# 110526             0         0       None         0             1      No
#
# [110527 rows x 13 columns]
